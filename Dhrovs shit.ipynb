# %%
import numpy as np
import pandas as pd
#import geopandas as gpd
#from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
#import descartes
#import pyproj



pd.options.display.max_columns = None

# %% [markdown]
# # airbnb

# %%
df = pd.read_csv('data/listings.csv', index_col='id')
df.head()
# Out:
# C:\Anaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                             listing_url       scrape_id last_scraped  \
# id
# 3647  https://www.airbnb.com/rooms/3647  20190912153101   2019-09-13
# 3831  https://www.airbnb.com/rooms/3831  20190912153101   2019-09-13
# 5022  https://www.airbnb.com/rooms/5022  20190912153101   2019-09-13
# 5099  https://www.airbnb.com/rooms/5099  20190912153101   2019-09-13
# 5121  https://www.airbnb.com/rooms/5121  20190912153101   2019-09-13
#
#                                                   name  \
# id
# 3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3831                   Cozy Entire Floor of Brownstone
# 5022  Entire Apt: Spacious Studio/Loft by central park
# 5099         Large Cozy 1 BR Apartment In Midtown East
# 5121                                   BlissArtsSpace!
#
#                                                 summary  \
# id
# 3647                                                NaN
# 3831  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 5022                                                NaN
# 5099  My large 1 bedroom apartment has a true New Yo...
# 5121                                                NaN
#
#                                                   space  \
# id
# 3647  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 3831  Greetings!      We own a double-duplex brownst...
# 5022  Loft apartment with high ceiling and wood floo...
# 5099  I have a large 1 bedroom apartment centrally l...
# 5121  HELLO EVERYONE AND THANKS FOR VISITING BLISS A...
#
#                                             description experiences_offered  \
# id
# 3647  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
# 3831  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 5022  Loft apartment with high ceiling and wood floo...                none
# 5099  My large 1 bedroom apartment has a true New Yo...                none
# 5121  HELLO EVERYONE AND THANKS FOR VISITING BLISS A...                none
#
#                                   neighborhood_overview  \
# id
# 3647                                                NaN
# 3831  Just the right mix of urban center and local n...
# 5022                                                NaN
# 5099  My neighborhood in Midtown East is called Murr...
# 5121                                                NaN
#
#                                                   notes  \
# id
# 3647                                                NaN
# 3831                                                NaN
# 5022                                                NaN
# 5099  Read My Full Listing For All Information. New ...
# 5121                                                NaN
#
#                                                 transit  \
# id
# 3647                                                NaN
# 3831  B52 bus for a 10-minute ride to downtown Brook...
# 5022                                                NaN
# 5099  From the apartment is a 10 minute walk to Gran...
# 5121                                                NaN
#
#                                                  access  \
# id
# 3647                                                NaN
# 3831  You will have exclusive use of and access to: ...
# 5022                                                NaN
# 5099                      I will meet you upon arrival.
# 5121                                                NaN
#
#                                             interaction  \
# id
# 3647                                                NaN
# 3831  We'll be around, but since you have the top fl...
# 5022                                                NaN
# 5099  I usually check in with guests via text or ema...
# 5121                                                NaN
#
#                                             house_rules  thumbnail_url  \
# id
# 3647  Upon arrival please have a legibile copy of yo...            NaN
# 3831  Smoking - outside please; pets allowed but ple...            NaN
# 5022  Please be considerate when staying in the apar...            NaN
# 5099  • Check-in time is 2PM. • Check-out time is 12...            NaN
# 5121                                                NaN            NaN
#
#       medium_url                                        picture_url  \
# id
# 3647         NaN  https://a0.muscache.com/im/pictures/838341/9b3...
# 3831         NaN  https://a0.muscache.com/im/pictures/e49999c2-9...
# 5022         NaN  https://a0.muscache.com/im/pictures/feb453bd-f...
# 5099         NaN  https://a0.muscache.com/im/pictures/6b9804f2-1...
# 5121         NaN  https://a0.muscache.com/im/pictures/2090980c-b...
#
#       xl_picture_url  host_id                                host_url  \
# id
# 3647             NaN     4632  https://www.airbnb.com/users/show/4632
# 3831             NaN     4869  https://www.airbnb.com/users/show/4869
# 5022             NaN     7192  https://www.airbnb.com/users/show/7192
# 5099             NaN     7322  https://www.airbnb.com/users/show/7322
# 5121             NaN     7356  https://www.airbnb.com/users/show/7356
#
#         host_name  host_since                      host_location  \
# id
# 3647    Elisabeth  2008-11-25  New York, New York, United States
# 3831  LisaRoxanne  2008-12-07  New York, New York, United States
# 5022        Laura  2009-01-29      Miami, Florida, United States
# 5099        Chris  2009-02-02  New York, New York, United States
# 5121        Garon  2009-02-03  New York, New York, United States
#
#                                              host_about  host_response_time  \
# id
# 3647  Make Up Artist National/ (Website hidden by Ai...  a few days or more
# 3831     Laid-back bi-coastal actor/professor/attorney.      within an hour
# 5022  I have been a NYer for almost 10 years. I came...                 NaN
# 5099  I'm an artist, writer, traveler, and a native ...        within a day
# 5121   I am an artist(painter, filmmaker) and curato...  a few days or more
#
#      host_response_rate  host_acceptance_rate host_is_superhost  \
# id
# 3647                 0%                   NaN                 f
# 3831                92%                   NaN                 f
# 5022                NaN                   NaN                 f
# 5099                78%                   NaN                 f
# 5121                 0%                   NaN                 f
#
#                                      host_thumbnail_url  \
# id
# 3647  https://a0.muscache.com/im/users/4632/profile_...
# 3831  https://a0.muscache.com/im/users/4869/profile_...
# 5022  https://a0.muscache.com/im/users/7192/profile_...
# 5099  https://a0.muscache.com/im/pictures/user/26745...
# 5121  https://a0.muscache.com/im/pictures/72a61bea-c...
#
#                                        host_picture_url  host_neighbourhood  \
# id
# 3647  https://a0.muscache.com/im/users/4632/profile_...              Harlem
# 3831  https://a0.muscache.com/im/users/4869/profile_...        Clinton Hill
# 5022  https://a0.muscache.com/im/users/7192/profile_...         East Harlem
# 5099  https://a0.muscache.com/im/pictures/user/26745...   Flatiron District
# 5121  https://a0.muscache.com/im/pictures/72a61bea-c...  Bedford-Stuyvesant
#
#       host_listings_count  host_total_listings_count  \
# id
# 3647                  1.0                        1.0
# 3831                  1.0                        1.0
# 5022                  1.0                        1.0
# 5099                  1.0                        1.0
# 5121                  1.0                        1.0
#
#                                      host_verifications host_has_profile_pic  \
# id
# 3647  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 3831               ['email', 'phone', 'reviews', 'kba']                    t
# 5022   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 5099  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 5121  ['email', 'phone', 'facebook', 'reviews', 'off...                    t
#
#      host_identity_verified                       street       neighbourhood  \
# id
# 3647                      t  New York, NY, United States              Harlem
# 3831                      t  Brooklyn, NY, United States            Brooklyn
# 5022                      t  New York, NY, United States         East Harlem
# 5099                      f  New York, NY, United States        Midtown East
# 5121                      f  Brooklyn, NY, United States  Bedford-Stuyvesant
#
#      neighbourhood_cleansed neighbourhood_group_cleansed      city state  \
# id
# 3647                 Harlem                    Manhattan  New York    NY
# 3831           Clinton Hill                     Brooklyn  Brooklyn    NY
# 5022            East Harlem                    Manhattan  New York    NY
# 5099            Murray Hill                    Manhattan  New York    NY
# 5121     Bedford-Stuyvesant                     Brooklyn  Brooklyn    NY
#
#      zipcode    market smart_location country_code        country  latitude  \
# id
# 3647   10027  New York   New York, NY           US  United States  40.80902
# 3831   11238  New York   Brooklyn, NY           US  United States  40.68514
# 5022   10029  New York   New York, NY           US  United States  40.79851
# 5099   10016  New York   New York, NY           US  United States  40.74767
# 5121   11216  New York   Brooklyn, NY           US  United States  40.68688
#
#       longitude is_location_exact property_type        room_type  \
# id
# 3647  -73.94190                 t     Apartment     Private room
# 3831  -73.95976                 t   Guest suite  Entire home/apt
# 5022  -73.94399                 t     Apartment  Entire home/apt
# 5099  -73.97500                 f     Apartment  Entire home/apt
# 5121  -73.95596                 f     Apartment     Private room
#
#       accommodates  bathrooms  bedrooms  beds       bed_type  \
# id
# 3647             2        1.0       1.0   1.0  Pull-out Sofa
# 3831             3        1.0       1.0   4.0       Real Bed
# 5022             1        1.0       NaN   1.0       Real Bed
# 5099             2        1.0       1.0   1.0       Real Bed
# 5121             2        NaN       1.0   1.0          Futon
#
#                                               amenities  square_feet    price  \
# id
# 3647  {"Cable TV",Internet,Wifi,"Air conditioning",K...          NaN  $150.00
# 3831  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        500.0   $89.00
# 5022  {Internet,Wifi,"Air conditioning",Kitchen,Elev...          NaN   $80.00
# 5099  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...          NaN  $200.00
# 5121  {Wifi,"Air conditioning",Kitchen,"Pets live on...          NaN   $60.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# id
# 3647          NaN           NaN          $200.00       $75.00
# 3831      $575.00     $2,100.00          $500.00          NaN
# 5022      $600.00     $1,600.00          $100.00       $80.00
# 5099          NaN           NaN          $300.00      $125.00
# 5121          NaN           NaN          $450.00        $0.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 3647                2       $20.00               3               7
# 3831                1        $0.00               1             730
# 5022                1       $20.00              10             120
# 5099                2      $100.00               3              21
# 5121                1       $30.00              45             730
#
#       minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# id
# 3647                       3                       3                       7
# 3831                       1                       1                     730
# 5022                      10                      10                     120
# 5099                       3                       3                      21
# 5121                      45                      45                     730
#
#       maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# id
# 3647                       7                     3.0                     7.0
# 3831                     730                     1.0                   730.0
# 5022                     120                    10.0                   120.0
# 5099                      21                     3.0                    21.0
# 5121                     730                    45.0                   730.0
#
#      calendar_updated has_availability  availability_30  availability_60  \
# id
# 3647    37 months ago                t               30               60
# 3831       3 days ago                t                1                3
# 5022     6 months ago                t                0                0
# 5099            today                t                3                3
# 5121    20 months ago                t                0                0
#
#       availability_90  availability_365 calendar_last_scraped  \
# id
# 3647               90               365            2019-09-13
# 3831                8               192            2019-09-13
# 5022                0                 0            2019-09-13
# 5099               13                13            2019-09-13
# 5121                0                 0            2019-09-13
#
#       number_of_reviews  number_of_reviews_ltm first_review last_review  \
# id
# 3647                  0                      0          NaN         NaN
# 3831                279                     67   2014-09-30  2019-08-29
# 5022                  9                      2   2012-03-20  2018-11-19
# 5099                 75                     10   2009-04-20  2019-07-21
# 5121                 49                      0   2009-05-28  2017-10-05
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# id
# 3647                   NaN                     NaN                        NaN
# 3831                  90.0                     9.0                        9.0
# 5022                  93.0                    10.0                        9.0
# 5099                  89.0                    10.0                        9.0
# 5121                  90.0                     8.0                        8.0
#
#       review_scores_checkin  review_scores_communication  \
# id
# 3647                    NaN                          NaN
# 3831                   10.0                          9.0
# 5022                   10.0                         10.0
# 5099                   10.0                         10.0
# 5121                   10.0                         10.0
#
#       review_scores_location  review_scores_value requires_license license  \
# id
# 3647                     NaN                  NaN                f     NaN
# 3831                    10.0                  9.0                f     NaN
# 5022                     9.0                 10.0                f     NaN
# 5099                     9.0                  9.0                f     NaN
# 5121                     9.0                  9.0                f     NaN
#
#      jurisdiction_names instant_bookable is_business_travel_ready  \
# id
# 3647                NaN                f                        f
# 3831                NaN                f                        f
# 5022                NaN                f                        f
# 5099                NaN                f                        f
# 5121                NaN                f                        f
#
#               cancellation_policy require_guest_profile_picture  \
# id
# 3647  strict_14_with_grace_period                             t
# 3831                     moderate                             f
# 5022  strict_14_with_grace_period                             t
# 5099                     moderate                             t
# 5121  strict_14_with_grace_period                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# id
# 3647                                t                               1
# 3831                                f                               1
# 5022                                t                               1
# 5099                                t                               1
# 5121                                f                               1
#
#       calculated_host_listings_count_entire_homes  \
# id
# 3647                                            0
# 3831                                            1
# 5022                                            1
# 5099                                            1
# 5121                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 3647                                             1
# 3831                                             0
# 5022                                             0
# 5099                                             0
# 5121                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 3647                                            0                NaN
# 3831                                            0               4.62
# 5022                                            0               0.10
# 5099                                            0               0.59
# 5121                                            0               0.39

# %% [markdown]
# ## Weak

# %% [markdown]
# transit-(in not null, treat as good)
# interaction-(would need to do text analysis to find the level of interaction)
# Name-house rules (proxy for host effort in creating profile. Check word counts, not null and such)
# host_location
# security_deposit
# cleaning_fee
# minimum_nights
# maximum_nights

# %% [markdown]
# ## Strong

# %% [markdown]
# host_is_superhost
# neighbourhood
# accommodates
# bed_type
# bathrooms
# bedrooms
# room_type
# property_type
# amenities
# number_of_reviews

# %%
new_df = df[['host_is_superhost',
'neighbourhood',
'accommodates',
'bed_type',
'bathrooms',
'bedrooms',
'room_type',
'property_type',
'amenities',
'number_of_reviews',
'price']]

# %%
new_df['host_is_superhost'][new_df['host_is_superhost']=='f'] = False
new_df['host_is_superhost'][new_df['host_is_superhost']=='t'] = True
# Out:
# C:\Anaconda\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda\envs\py36\lib\site-packages\pandas\core\generic.py:9114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Anaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:3319: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Anaconda\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from money_parser import price_dec
df['price'].map(lambda v: float(price_dec(v))).hist(bins=30);

# %%
(df['host_location'] == 'New York, New York, United States').value_counts()
# Out:
# True     31537
# False    16840
# Name: host_location, dtype: int64

# %%
#USE PRICE AS THE REGRESSOR AS IT HAS MOST DATA. WEEKLY AND MONTHLY ARE SPARSE
df['price'].isnull().value_counts()

df['weekly_price'].isnull().value_counts()
df['monthly_price'].isnull().value_counts()
# Out:
# True     43376
# False     5001
# Name: monthly_price, dtype: int64

# %% [markdown]
# ## Census

# %%
census_df = pd.read_csv('data/nyc_census_tracts.csv')
census_blocks_df = pd.read_csv('data/census_block_loc.csv')

# %%
census_blocks_df['CensusTract'] = census_blocks_df['BlockCode'].apply(lambda v: int(str(v)[:-4]))
tract_to_coords_df = census_blocks_df.drop('BlockCode', axis='columns').groupby('CensusTract').mean()
census_all_df = tract_to_coords_df.reset_index().merge(census_df, on='CensusTract', how='right')
census_all_df = census_all_df[census_all_df['Latitude'].notnull()]

# %%
census_all_df
# Out:
#       CensusTract   Latitude  Longitude    County        Borough  TotalPop  \
# 0     36005000100  40.792756 -73.883541     Bronx          Bronx      7703
# 1     36005000200  40.805866 -73.860278     Bronx          Bronx      5403
# 2     36005000400  40.807594 -73.851237     Bronx          Bronx      5915
# 3     36005001600  40.819196 -73.858040     Bronx          Bronx      5879
# 4     36005001900  40.801216 -73.909212     Bronx          Bronx      2591
# ...           ...        ...        ...       ...            ...       ...
# 2147  36085030302  40.623367 -74.158221  Richmond  Staten Island      6279
# 2148  36085031901  40.630377 -74.163920  Richmond  Staten Island      2550
# 2149  36085031902  40.639422 -74.166256  Richmond  Staten Island      4611
# 2150  36085032300  40.635312 -74.179497  Richmond  Staten Island      1131
# 2151  36085990100  40.525643 -74.108511  Richmond  Staten Island         0
#
#        Men  Women  Hispanic  White  Black  Native  Asian  Citizen   Income  \
# 0     7133    570      29.9    6.1   60.9     0.2    1.6     6476      NaN
# 1     2659   2744      75.8    2.3   16.0     0.0    4.2     3639  72034.0
# 2     2896   3019      62.7    3.6   30.7     0.0    0.3     4100  74836.0
# 3     2558   3321      65.1    1.6   32.4     0.0    0.0     3536  32312.0
# 4     1206   1385      55.4    9.0   29.0     0.0    2.1     1557  37936.0
# ...    ...    ...       ...    ...    ...     ...    ...      ...      ...
# 2147  3093   3186      35.8   28.7   17.6     0.0   14.3     3842  76542.0
# 2148   953   1597      27.1    6.2   60.4     0.0    6.3     1558  25064.0
# 2149  2043   2568      20.9   14.7   61.9     0.0    0.9     2649  22656.0
# 2150   597    534      45.5   24.0   29.7     0.0    0.0      768  56406.0
# 2151     0      0       NaN    NaN    NaN     NaN    NaN        0      NaN
#
#       IncomeErr  IncomePerCap  IncomePerCapErr  Poverty  ChildPoverty  \
# 0           NaN        2440.0            373.0      NaN           NaN
# 1       13991.0       22180.0           2206.0     20.0          20.7
# 2        8407.0       27700.0           2449.0     13.2          23.6
# 3        6859.0       17526.0           2945.0     26.3          35.9
# 4        3771.0       17986.0           2692.0     37.1          31.5
# ...         ...           ...              ...      ...           ...
# 2147     8095.0       25189.0           3131.0     19.0          27.8
# 2148     7879.0       12753.0           2439.0     39.3          51.4
# 2149     8776.0       16303.0           2818.0     41.2          53.8
# 2150    22600.0       34261.0          10543.0     20.5          16.5
# 2151        NaN           NaN              NaN      NaN           NaN
#
#       Professional  Service  Office  Construction  Production  Drive  Carpool  \
# 0              NaN      NaN     NaN           NaN         NaN    NaN      NaN
# 1             28.7     17.1    23.9           8.0        22.3   44.8     13.7
# 2             32.2     23.4    24.9           9.0        10.5   41.3     10.0
# 3             19.1     36.1    26.2           4.9        13.8   37.2      5.3
# 4             35.4     20.9    26.2           6.6        11.0   19.2      5.3
# ...            ...      ...     ...           ...         ...    ...      ...
# 2147          35.8     20.6    23.3           8.4        12.0   53.8      8.9
# 2148          29.7     30.6    21.1           7.3        11.3   38.7      2.4
# 2149          31.0     37.7    18.1           6.1         7.1   44.9      7.2
# 2150          26.2     21.0    34.8           2.8        15.2   53.6      8.8
# 2151           NaN      NaN     NaN           NaN         NaN    NaN      NaN
#
#       Transit  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0         NaN   NaN          NaN         NaN          NaN         0
# 1        38.6   2.9          0.0         0.0         43.0      2308
# 2        44.6   1.4          0.5         2.1         45.0      2675
# 3        45.5   8.6          1.6         1.7         38.8      2120
# 4        63.9   3.0          2.4         6.2         45.4      1083
# ...       ...   ...          ...         ...          ...       ...
# 2147     35.1   0.9          0.0         1.3         46.6      2668
# 2148     49.4   9.5          0.0         0.0         38.2       710
# 2149     44.5   0.5          0.0         2.7         40.9      1308
# 2150     32.8   4.9          0.0         0.0         52.5       534
# 2151      NaN   NaN          NaN         NaN          NaN         0
#
#       PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0             NaN         NaN           NaN         NaN           NaN
# 1            80.8        16.2           2.9         0.0           7.7
# 2            71.7        25.3           2.5         0.6           9.5
# 3            75.0        21.3           3.8         0.0           8.7
# 4            76.8        15.5           7.7         0.0          19.2
# ...           ...         ...           ...         ...           ...
# 2147         74.4        22.5           3.2         0.0           6.2
# 2148         73.8        21.8           4.4         0.0          13.8
# 2149         84.7        12.6           2.7         0.0           9.4
# 2150         65.0        31.1           3.9         0.0          10.7
# 2151          NaN         NaN           NaN         NaN           NaN
#
# [2152 rows x 38 columns]

# %%
census_all_df.groupby('CensusTract')[['Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr']].mean()
# Out:
#               Income  IncomeErr  IncomePerCap  IncomePerCapErr
# CensusTract
# 36005000100      NaN        NaN        2440.0            373.0
# 36005000200  72034.0    13991.0       22180.0           2206.0
# 36005000400  74836.0     8407.0       27700.0           2449.0
# 36005001600  32312.0     6859.0       17526.0           2945.0
# 36005001900  37936.0     3771.0       17986.0           2692.0
# ...              ...        ...           ...              ...
# 36085030302  76542.0     8095.0       25189.0           3131.0
# 36085031901  25064.0     7879.0       12753.0           2439.0
# 36085031902  22656.0     8776.0       16303.0           2818.0
# 36085032300  56406.0    22600.0       34261.0          10543.0
# 36085990100      NaN        NaN           NaN              NaN
#
# [2152 rows x 4 columns]

# %%
census_all_df
# Out:
#       CensusTract   Latitude  Longitude    County        Borough  TotalPop  \
# 0     36005000100  40.792756 -73.883541     Bronx          Bronx      7703
# 1     36005000200  40.805866 -73.860278     Bronx          Bronx      5403
# 2     36005000400  40.807594 -73.851237     Bronx          Bronx      5915
# 3     36005001600  40.819196 -73.858040     Bronx          Bronx      5879
# 4     36005001900  40.801216 -73.909212     Bronx          Bronx      2591
# ...           ...        ...        ...       ...            ...       ...
# 2147  36085030302  40.623367 -74.158221  Richmond  Staten Island      6279
# 2148  36085031901  40.630377 -74.163920  Richmond  Staten Island      2550
# 2149  36085031902  40.639422 -74.166256  Richmond  Staten Island      4611
# 2150  36085032300  40.635312 -74.179497  Richmond  Staten Island      1131
# 2151  36085990100  40.525643 -74.108511  Richmond  Staten Island         0
#
#        Men  Women  Hispanic  White  Black  Native  Asian  Citizen   Income  \
# 0     7133    570      29.9    6.1   60.9     0.2    1.6     6476      NaN
# 1     2659   2744      75.8    2.3   16.0     0.0    4.2     3639  72034.0
# 2     2896   3019      62.7    3.6   30.7     0.0    0.3     4100  74836.0
# 3     2558   3321      65.1    1.6   32.4     0.0    0.0     3536  32312.0
# 4     1206   1385      55.4    9.0   29.0     0.0    2.1     1557  37936.0
# ...    ...    ...       ...    ...    ...     ...    ...      ...      ...
# 2147  3093   3186      35.8   28.7   17.6     0.0   14.3     3842  76542.0
# 2148   953   1597      27.1    6.2   60.4     0.0    6.3     1558  25064.0
# 2149  2043   2568      20.9   14.7   61.9     0.0    0.9     2649  22656.0
# 2150   597    534      45.5   24.0   29.7     0.0    0.0      768  56406.0
# 2151     0      0       NaN    NaN    NaN     NaN    NaN        0      NaN
#
#       IncomeErr  IncomePerCap  IncomePerCapErr  Poverty  ChildPoverty  \
# 0           NaN        2440.0            373.0      NaN           NaN
# 1       13991.0       22180.0           2206.0     20.0          20.7
# 2        8407.0       27700.0           2449.0     13.2          23.6
# 3        6859.0       17526.0           2945.0     26.3          35.9
# 4        3771.0       17986.0           2692.0     37.1          31.5
# ...         ...           ...              ...      ...           ...
# 2147     8095.0       25189.0           3131.0     19.0          27.8
# 2148     7879.0       12753.0           2439.0     39.3          51.4
# 2149     8776.0       16303.0           2818.0     41.2          53.8
# 2150    22600.0       34261.0          10543.0     20.5          16.5
# 2151        NaN           NaN              NaN      NaN           NaN
#
#       Professional  Service  Office  Construction  Production  Drive  Carpool  \
# 0              NaN      NaN     NaN           NaN         NaN    NaN      NaN
# 1             28.7     17.1    23.9           8.0        22.3   44.8     13.7
# 2             32.2     23.4    24.9           9.0        10.5   41.3     10.0
# 3             19.1     36.1    26.2           4.9        13.8   37.2      5.3
# 4             35.4     20.9    26.2           6.6        11.0   19.2      5.3
# ...            ...      ...     ...           ...         ...    ...      ...
# 2147          35.8     20.6    23.3           8.4        12.0   53.8      8.9
# 2148          29.7     30.6    21.1           7.3        11.3   38.7      2.4
# 2149          31.0     37.7    18.1           6.1         7.1   44.9      7.2
# 2150          26.2     21.0    34.8           2.8        15.2   53.6      8.8
# 2151           NaN      NaN     NaN           NaN         NaN    NaN      NaN
#
#       Transit  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0         NaN   NaN          NaN         NaN          NaN         0
# 1        38.6   2.9          0.0         0.0         43.0      2308
# 2        44.6   1.4          0.5         2.1         45.0      2675
# 3        45.5   8.6          1.6         1.7         38.8      2120
# 4        63.9   3.0          2.4         6.2         45.4      1083
# ...       ...   ...          ...         ...          ...       ...
# 2147     35.1   0.9          0.0         1.3         46.6      2668
# 2148     49.4   9.5          0.0         0.0         38.2       710
# 2149     44.5   0.5          0.0         2.7         40.9      1308
# 2150     32.8   4.9          0.0         0.0         52.5       534
# 2151      NaN   NaN          NaN         NaN          NaN         0
#
#       PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0             NaN         NaN           NaN         NaN           NaN
# 1            80.8        16.2           2.9         0.0           7.7
# 2            71.7        25.3           2.5         0.6           9.5
# 3            75.0        21.3           3.8         0.0           8.7
# 4            76.8        15.5           7.7         0.0          19.2
# ...           ...         ...           ...         ...           ...
# 2147         74.4        22.5           3.2         0.0           6.2
# 2148         73.8        21.8           4.4         0.0          13.8
# 2149         84.7        12.6           2.7         0.0           9.4
# 2150         65.0        31.1           3.9         0.0          10.7
# 2151          NaN         NaN           NaN         NaN           NaN
#
# [2152 rows x 38 columns]

# %% [markdown]
# ## Crime

# %%
crime_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f33b5f78d767> in <module>
# ----> 1 crime_df
#
# NameError: name 'crime_df' is not defined

# %% [markdown]
# ## REGRESS WITH CENSUS & CRIME

# %%
from money_parser import price_dec
import lightgbm as lgbm

from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import mean_squared_error, make_scorer

# %%
crime_df

# %%
# def curr_to_float(v): return float(price_dec(v)) if v else v
# def tf_to_10(v): return 1 if v == 't' else 0
# def nulls_to_0(v): return float(0 if (pd.isnull(v) or v == '') else v)

# converters_to_columns = [
#     (curr_to_float, ['price', 'weekly_price', 'monthly_price']),
#     (tf_to_10, ['instant_bookable', 'host_is_superhost']),
#     (nulls_to_0, ['bedrooms', 'bathrooms'])
# ]

# converters = {col: conv for conv, cols in converters_to_columns for col in cols}

# df = pd.read_csv('data/listingwithcensus.csv', index_col='id', converters=converters)
# df.rename(columns={"census_tracts": "CensusTract"},inplace= True)

# df.drop(['scrape_id', 'listing_url', 'last_scraped', 'space', 'description', 
#          'picture_url', 'host_url', 'host_thumbnail_url', 'country', 'market', 
#          'host_picture_url'], axis='columns')

# newdf = pd.merge(df, census_all_df, how='left', on='CensusTract').set_index(df['id'])
# #newdf = df.reset_index().merge(census_all_df, how="left").set_index('id')

# ACeCr = pd.merge(newdf, crime_df, on='id')

# %%
ACeCr = pd.read_csv('data/old_listings_all.csv', index_col=0)
# Out:
# C:\Anaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
amenities_list = ['Heating', 'Kitchen', 'Air conditioning', 'Hangers', 'Hair dryer', 'Shampoo', 'Iron', 'Laptop friendly workspace',
                  'Hot water', 'Family/kid friendly', 'Coffee maker', 'Extra pillows and blankets', 'Luggage dropoff allowed'
                  ,'No stairs or steps to enter', 'Lock on bedroom door'] 
adjectives = ['private','new','spacious','cozy','great','beautiful','heart','large','quiet','clean','modern','comfortable','perfect','best',
'sunny','renovated','bright','available']

ACeCr['Wifi'] = np.where((ACeCr['amenities'].str.contains('Wifi') | ACeCr['amenities'].str.contains('Internet')),1,0)
ACeCr['TV'] = np.where((ACeCr['amenities'].str.contains('TV') | ACeCr['amenities'].str.contains('Cable TV')),1,0)
ACeCr['Self check-in'] = np.where((ACeCr['amenities'].str.contains('Self check-in') | ACeCr['amenities'].str.contains('24-hour check-in')),1,0)
ACeCr['Free parking'] = np.where((ACeCr['amenities'].str.contains('Free street parking') | ACeCr['amenities'].str.contains('Free parking on premises')),1,0)
ACeCr['Pets allowed'] = np.where((ACeCr['amenities'].str.contains('Pets allowed') | ACeCr['amenities'].str.contains('Cat(s)') | ACeCr['amenities'].str.contains('Dog(s)')),1,0)
ACeCr['Pets on property'] = np.where(ACeCr['amenities'].str.contains('Pets live on this property'),1,0)

for i in amenities_list:
    ACeCr[i] = np.where(ACeCr['amenities'].str.contains(i),1,0)
    
ACeCr['text'] = ACeCr['name'] + ' ' + ACeCr['summary']

for adj in adjectives:
    ACeCr[adj] = np.where(ACeCr['text'].str.contains(adj),1,0)
    
hoods = np.unique(df['neighbourhood_cleansed'].to_numpy())

for hood in hoods:
    ACeCr[hood] = np.where(ACeCr['neighbourhood_cleansed'].str.contains(hood),1,0)

      
ACeCr
# Out:
#                                     listing_url       scrape_id last_scraped  \
# id
# 3647          https://www.airbnb.com/rooms/3647  20190912153101   2019-09-13
# 25696        https://www.airbnb.com/rooms/25696  20190912153101   2019-09-13
# 57874        https://www.airbnb.com/rooms/57874  20190912153101   2019-09-13
# 234184      https://www.airbnb.com/rooms/234184  20190912153101   2019-09-13
# 250536      https://www.airbnb.com/rooms/250536  20190912153101   2019-09-13
# ...                                         ...             ...          ...
# 38392995  https://www.airbnb.com/rooms/38392995  20190912153101   2019-09-13
# 38404073  https://www.airbnb.com/rooms/38404073  20190912153101   2019-09-13
# 38489399  https://www.airbnb.com/rooms/38489399  20190912153101   2019-09-13
# 38492461  https://www.airbnb.com/rooms/38492461  20190912153101   2019-09-13
# 38495716  https://www.airbnb.com/rooms/38495716  20190912153101   2019-09-13
#
#                                                        name  \
# id
# 3647                    THE VILLAGE OF HARLEM....NEW YORK !
# 25696                      1,800 sq foot in luxury building
# 57874                    The Brownstone-Luxury 1 Bd Apt/NYC
# 234184                   Spacious Stunning Harlem Townhouse
# 250536                                  The Lenox in Harlem
# ...                                                     ...
# 38392995                     Rooms available for rent ASAP.
# 38404073                                  Chic and Peaceful
# 38489399                    Bronx private room in apartment
# 38492461  Bronx Private Room w Shared Bathroom - No Parking
# 38495716                                 Quiet neighborhood
#
#                                                     summary  \
# id
# 3647                                                    NaN
# 25696                                                   NaN
# 57874     Gorgeous, spacious and sun filled New York 1 B...
# 234184    Live like a New Yorker in this modern townhous...
# 250536    This private room with a private bath is locat...
# ...                                                     ...
# 38392995                                                NaN
# 38404073  Chic and spacious space,  perfect for lounging...
# 38489399  Apartment on the 8th floor with a view of Manh...
# 38492461  Excellent neighborhood. 15 Minute Walk to 6 Tr...
# 38495716  A quiet neighborhood  close to public transpor...
#
#                                                       space  \
# id
# 3647      WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 25696     The apartment has 3 bedrooms/2 baths. I live i...
# 57874     Please note that there are twelve photos of th...
# 234184    ULTIMATE Luxury! Home features three floors an...
# 250536    This beautiful, spacious apartment is just 4 b...
# ...                                                     ...
# 38392995                                                NaN
# 38404073                       Chic and peaceful apartment.
# 38489399                                                NaN
# 38492461                                                NaN
# 38495716                                                NaN
#
#                                                 description  \
# id
# 3647      WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 25696     The apartment has 3 bedrooms/2 baths. I live i...
# 57874     Gorgeous, spacious and sun filled New York 1 B...
# 234184    Live like a New Yorker in this modern townhous...
# 250536    This private room with a private bath is locat...
# ...                                                     ...
# 38392995                                                NaN
# 38404073  Chic and spacious space,  perfect for lounging...
# 38489399  Apartment on the 8th floor with a view of Manh...
# 38492461  Excellent neighborhood. 15 Minute Walk to 6 Tr...
# 38495716  A quiet neighborhood  close to public transpor...
#
#          experiences_offered  \
# id
# 3647                    none
# 25696                   none
# 57874                   none
# 234184                  none
# 250536                  none
# ...                      ...
# 38392995                none
# 38404073                none
# 38489399                none
# 38492461                none
# 38495716                none
#
#                                       neighborhood_overview  \
# id
# 3647                                                    NaN
# 25696                    It's full of energy and character.
# 57874     Fantastic and vibrant neighborhood. Area highl...
# 234184    ABOUT THE NEIGHBORHOOD/LOCATION: - Harlem is t...
# 250536                                                  NaN
# ...                                                     ...
# 38392995                                                NaN
# 38404073  The apartment is situated across the street fr...
# 38489399                                                NaN
# 38492461                                                NaN
# 38495716  Bronx zoo, botanical gardens, Italian restaura...
#
#                                                       notes  \
# id
# 3647                                                    NaN
# 25696     I'm often asked about the safety of the neighb...
# 57874                                                   NaN
# 234184    INCLUDED IN NIGHTLY RATE: - Towels and linens....
# 250536                                                  NaN
# ...                                                     ...
# 38392995                                                NaN
# 38404073                                                NaN
# 38489399                                                NaN
# 38492461                                                NaN
# 38495716                                                NaN
#
#                                                     transit  \
# id
# 3647                                                    NaN
# 25696     The apartment is 4 blocks from the express 2/3...
# 57874     The apartment is centrally located: best way a...
# 234184    You are in Manhattan 10-15 minutes away from T...
# 250536                                                  NaN
# ...                                                     ...
# 38392995                                                NaN
# 38404073  There is an express coach bus on the corner of...
# 38489399                                                NaN
# 38492461                                                NaN
# 38495716  2 train Buses bx39, bx22,bx 21 Express bus to ...
#
#                                           access  \
# id
# 3647                                         NaN
# 25696     The kitchen, the living room, the gym.
# 57874              Guest has access to all areas
# 234184                                       NaN
# 250536                                       NaN
# ...                                          ...
# 38392995                                     NaN
# 38404073                                     NaN
# 38489399                                     NaN
# 38492461                                     NaN
# 38495716                                     NaN
#
#                                                 interaction  \
# id
# 3647                                                    NaN
# 25696                         as much or little as you want
# 57874     We pride ourselves on helping our guests have ...
# 234184                                                  NaN
# 250536                                                  NaN
# ...                                                     ...
# 38392995                                                NaN
# 38404073  I am just a quick call/text away if you need a...
# 38489399                                                NaN
# 38492461                                                NaN
# 38495716                                                NaN
#
#                                                 house_rules  thumbnail_url  \
# id
# 3647      Upon arrival please have a legibile copy of yo...            NaN
# 25696     No smoking in the apartment.  You will be expe...            NaN
# 57874     Thank you for your interest in the Brownstone!...            NaN
# 234184    Due to allergy concerns: No Smoking, No Pets T...            NaN
# 250536                                                  NaN            NaN
# ...                                                     ...            ...
# 38392995                                                NaN            NaN
# 38404073       No loud music please. Especially after 11pm.            NaN
# 38489399                                                NaN            NaN
# 38492461     No Cleaning Fee - Must Clean Up After Yourself            NaN
# 38495716                        No smoking inside the house            NaN
#
#           medium_url                                        picture_url  \
# id
# 3647             NaN  https://a0.muscache.com/im/pictures/838341/9b3...
# 25696            NaN  https://a0.muscache.com/im/pictures/26334762/a...
# 57874            NaN  https://a0.muscache.com/im/pictures/636607/798...
# 234184           NaN  https://a0.muscache.com/im/pictures/57f95ec2-f...
# 250536           NaN  https://a0.muscache.com/im/pictures/2626723/f0...
# ...              ...                                                ...
# 38392995         NaN  https://a0.muscache.com/im/pictures/df6f7132-b...
# 38404073         NaN  https://a0.muscache.com/im/pictures/3111d2b4-4...
# 38489399         NaN  https://a0.muscache.com/im/pictures/cf9b4e93-f...
# 38492461         NaN  https://a0.muscache.com/im/pictures/476c51b8-9...
# 38495716         NaN  https://a0.muscache.com/im/pictures/fbd24b10-d...
#
#           xl_picture_url    host_id  \
# id
# 3647                 NaN       4632
# 25696                NaN     107628
# 57874                NaN     276291
# 234184               NaN     902054
# 250536               NaN    1313306
# ...                  ...        ...
# 38392995             NaN  200546815
# 38404073             NaN  237463039
# 38489399             NaN   23553128
# 38492461             NaN   58478540
# 38495716             NaN  293554399
#
#                                              host_url  host_name  host_since  \
# id
# 3647           https://www.airbnb.com/users/show/4632  Elisabeth  2008-11-25
# 25696        https://www.airbnb.com/users/show/107628       Dena  2010-04-12
# 57874        https://www.airbnb.com/users/show/276291      Simon  2010-11-01
# 234184       https://www.airbnb.com/users/show/902054    William  2011-08-01
# 250536      https://www.airbnb.com/users/show/1313306     Yvette  2011-10-19
# ...                                               ...        ...         ...
# 38392995  https://www.airbnb.com/users/show/200546815     Daniel  2018-07-07
# 38404073  https://www.airbnb.com/users/show/237463039   Victoria  2019-01-18
# 38489399   https://www.airbnb.com/users/show/23553128        Max  2014-11-10
# 38492461   https://www.airbnb.com/users/show/58478540    Armando  2016-02-12
# 38495716  https://www.airbnb.com/users/show/293554399      Erika  2019-09-09
#
#                                     host_location  \
# id
# 3647            New York, New York, United States
# 25696           New York, New York, United States
# 57874           New York, New York, United States
# 234184          New York, New York, United States
# 250536          New York, New York, United States
# ...                                           ...
# 38392995        New York, New York, United States
# 38404073                                       US
# 38489399  Walnut Creek, California, United States
# 38492461   East Orange, New Jersey, United States
# 38495716                                       US
#
#                                                  host_about  \
# id
# 3647      Make Up Artist National/ (Website hidden by Ai...
# 25696     i like meeting new people from all over the wo...
# 57874     We are a hard-working property management team...
# 234184    The apartment is owned and hosted by Will & fa...
# 250536    I live in New York City and love tennis and tr...
# ...                                                     ...
# 38392995                                                NaN
# 38404073                                                NaN
# 38489399                                                NaN
# 38492461              Outgoing, friendly, kind and fun.\n\n
# 38495716                                                NaN
#
#           host_response_time host_response_rate  host_acceptance_rate  \
# id
# 3647      a few days or more                 0%                   NaN
# 25696         within an hour               100%                   NaN
# 57874         within an hour               100%                   NaN
# 234184        within an hour               100%                   NaN
# 250536    within a few hours                88%                   NaN
# ...                      ...                ...                   ...
# 38392995                 NaN                NaN                   NaN
# 38404073  a few days or more                17%                   NaN
# 38489399                 NaN                NaN                   NaN
# 38492461      within an hour               100%                   NaN
# 38495716                 NaN                NaN                   NaN
#
#           host_is_superhost  \
# id
# 3647                      0
# 25696                     0
# 57874                     1
# 234184                    1
# 250536                    0
# ...                     ...
# 38392995                  0
# 38404073                  0
# 38489399                  0
# 38492461                  0
# 38495716                  0
#
#                                          host_thumbnail_url  \
# id
# 3647      https://a0.muscache.com/im/users/4632/profile_...
# 25696     https://a0.muscache.com/im/users/107628/profil...
# 57874     https://a0.muscache.com/im/users/276291/profil...
# 234184    https://a0.muscache.com/im/pictures/0fa75137-b...
# 250536    https://a0.muscache.com/im/users/1313306/profi...
# ...                                                     ...
# 38392995  https://a0.muscache.com/im/pictures/user/5058b...
# 38404073  https://a0.muscache.com/im/pictures/user/0d363...
# 38489399  https://a0.muscache.com/im/pictures/2100ed95-9...
# 38492461  https://a0.muscache.com/im/pictures/c5d6ea1d-a...
# 38495716  https://a0.muscache.com/im/pictures/user/ee6ae...
#
#                                            host_picture_url  \
# id
# 3647      https://a0.muscache.com/im/users/4632/profile_...
# 25696     https://a0.muscache.com/im/users/107628/profil...
# 57874     https://a0.muscache.com/im/users/276291/profil...
# 234184    https://a0.muscache.com/im/pictures/0fa75137-b...
# 250536    https://a0.muscache.com/im/users/1313306/profi...
# ...                                                     ...
# 38392995  https://a0.muscache.com/im/pictures/user/5058b...
# 38404073  https://a0.muscache.com/im/pictures/user/0d363...
# 38489399  https://a0.muscache.com/im/pictures/2100ed95-9...
# 38492461  https://a0.muscache.com/im/pictures/c5d6ea1d-a...
# 38495716  https://a0.muscache.com/im/pictures/user/ee6ae...
#
#          host_neighbourhood  host_listings_count  host_total_listings_count  \
# id
# 3647                 Harlem                  1.0                        1.0
# 25696                Harlem                  1.0                        1.0
# 57874                Harlem                  2.0                        2.0
# 234184               Harlem                  1.0                        1.0
# 250536               Harlem                  2.0                        2.0
# ...                     ...                  ...                        ...
# 38392995                NaN                  1.0                        1.0
# 38404073          Bay Ridge                  1.0                        1.0
# 38489399        Morris Park                  0.0                        0.0
# 38492461       Country Club                 13.0                       13.0
# 38495716           Van Nest                  0.0                        0.0
#
#                                          host_verifications  \
# id
# 3647      ['email', 'phone', 'google', 'reviews', 'jumio...
# 25696     ['email', 'phone', 'reviews', 'offline_governm...
# 57874     ['email', 'phone', 'reviews', 'offline_governm...
# 234184    ['email', 'phone', 'reviews', 'offline_governm...
# 250536                 ['email', 'phone', 'reviews', 'kba']
# ...                                                     ...
# 38392995                   ['email', 'phone', 'work_email']
# 38404073                                          ['phone']
# 38489399  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 38492461  ['email', 'phone', 'offline_government_id', 'k...
# 38495716                                 ['email', 'phone']
#
#          host_has_profile_pic host_identity_verified  \
# id
# 3647                        t                      t
# 25696                       t                      f
# 57874                       t                      t
# 234184                      t                      f
# 250536                      t                      t
# ...                       ...                    ...
# 38392995                    t                      f
# 38404073                    t                      f
# 38489399                    t                      t
# 38492461                    t                      f
# 38495716                    t                      f
#
#                                 street neighbourhood neighbourhood_cleansed  \
# id
# 3647       New York, NY, United States        Harlem                 Harlem
# 25696      New York, NY, United States     Manhattan                 Harlem
# 57874      New York, NY, United States        Harlem                 Harlem
# 234184     New York, NY, United States        Harlem                 Harlem
# 250536     New York, NY, United States        Harlem                 Harlem
# ...                                ...           ...                    ...
# 38392995     Bronx , NY, United States     The Bronx              Wakefield
# 38404073   Brooklyn, NY, United States      Brooklyn          Fort Hamilton
# 38489399  The Bronx, NY, United States     The Bronx            Morris Park
# 38492461  The Bronx, NY, United States     The Bronx           Country Club
# 38495716  The Bronx, NY, United States     The Bronx               Van Nest
#
#          neighbourhood_group_cleansed       city state zipcode    market  \
# id
# 3647                        Manhattan   New York    NY   10027  New York
# 25696                       Manhattan   New York    NY   10027  New York
# 57874                       Manhattan   New York    NY   10027  New York
# 234184                      Manhattan   New York    NY   10027  New York
# 250536                      Manhattan   New York    NY   10027  New York
# ...                               ...        ...   ...     ...       ...
# 38392995                        Bronx     Bronx     NY   10466  New York
# 38404073                     Brooklyn   Brooklyn    NY   11209  New York
# 38489399                        Bronx  The Bronx    NY   10461  New York
# 38492461                        Bronx  The Bronx    NY   10465  New York
# 38495716                        Bronx  The Bronx    NY   10462  New York
#
#          smart_location country_code        country  latitude  longitude  \
# id
# 3647       New York, NY           US  United States  40.80902  -73.94190
# 25696      New York, NY           US  United States  40.80920  -73.94421
# 57874      New York, NY           US  United States  40.80931  -73.94343
# 234184     New York, NY           US  United States  40.80903  -73.94197
# 250536     New York, NY           US  United States  40.81068  -73.94288
# ...                 ...          ...            ...       ...        ...
# 38392995     Bronx , NY           US  United States  40.89665  -73.84694
# 38404073   Brooklyn, NY           US  United States  40.61806  -74.03870
# 38489399  The Bronx, NY           US  United States  40.85264  -73.85562
# 38492461  The Bronx, NY           US  United States  40.84267  -73.82126
# 38495716  The Bronx, NY           US  United States  40.84806  -73.86440
#
#          is_location_exact property_type        room_type  accommodates  \
# id
# 3647                     t     Apartment     Private room             2
# 25696                    t     Apartment     Private room             2
# 57874                    t     Apartment  Entire home/apt             2
# 234184                   t     Townhouse  Entire home/apt             8
# 250536                   t   Condominium     Private room             2
# ...                    ...           ...              ...           ...
# 38392995                 f         House     Private room             1
# 38404073                 t     Apartment  Entire home/apt             2
# 38489399                 t     Apartment     Private room             1
# 38492461                 t     Apartment     Private room             2
# 38495716                 t         House     Private room             2
#
#           bathrooms  bedrooms  beds       bed_type  \
# id
# 3647            1.0       1.0   1.0  Pull-out Sofa
# 25696           1.0       1.0   1.0       Real Bed
# 57874           1.0       1.0   1.0       Real Bed
# 234184          2.0       4.0   5.0       Real Bed
# 250536          1.0       1.0   1.0       Real Bed
# ...             ...       ...   ...            ...
# 38392995        1.0       1.0   1.0       Real Bed
# 38404073        1.0       1.0   1.0       Real Bed
# 38489399        1.0       1.0   1.0       Real Bed
# 38492461        1.0       1.0   1.0       Real Bed
# 38495716        1.0       1.0   0.0       Real Bed
#
#                                                   amenities  square_feet  \
# id
# 3647      {"Cable TV",Internet,Wifi,"Air conditioning",K...          NaN
# 25696     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
# 57874     {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 234184    {TV,"Cable TV",Internet,Wifi,"Air conditioning...       2400.0
# 250536    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
# ...                                                     ...          ...
# 38392995  {"Free parking on premises","Smoking allowed",...          NaN
# 38404073  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...          NaN
# 38489399  {Wifi,"Air conditioning",Kitchen,Elevator,Heat...          NaN
# 38492461  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...          NaN
# 38495716  {"Free street parking","Smoke detector","Carbo...          NaN
#
#           price  weekly_price  monthly_price security_deposit cleaning_fee  \
# id
# 3647      150.0           NaN            NaN          $200.00       $75.00
# 25696     100.0           NaN            NaN          $100.00       $60.00
# 57874     155.0           NaN            NaN          $240.00       $70.00
# 234184    325.0        2100.0         5000.0            $0.00      $150.00
# 250536    125.0         850.0         2250.0            $0.00      $125.00
# ...         ...           ...            ...              ...          ...
# 38392995  200.0           NaN            NaN              NaN          NaN
# 38404073   66.0           NaN            NaN              NaN          NaN
# 38489399   80.0           NaN            NaN              NaN          NaN
# 38492461   69.0           NaN            NaN            $0.00        $0.00
# 38495716   70.0           NaN            NaN              NaN          NaN
#
#           guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 3647                    2       $20.00               3               7
# 25696                   1        $0.00               2              14
# 57874                   2       $70.00               3             365
# 234184                  6       $50.00               5             365
# 250536                  2       $50.00               1             365
# ...                   ...          ...             ...             ...
# 38392995                1        $0.00               1            1125
# 38404073                1        $0.00               2               7
# 38489399                1        $0.00               1            1125
# 38492461                1       $20.00               1            1125
# 38495716                1        $0.00               1               1
#
#           minimum_minimum_nights  maximum_minimum_nights  \
# id
# 3647                           3                       3
# 25696                          2                       2
# 57874                          3                       3
# 234184                         3                       5
# 250536                         1                       1
# ...                          ...                     ...
# 38392995                       1                       1
# 38404073                       2                       2
# 38489399                       1                       1
# 38492461                       1                       1
# 38495716                       1                       1
#
#           minimum_maximum_nights  maximum_maximum_nights  \
# id
# 3647                           7                       7
# 25696                         14                      14
# 57874                        365                     365
# 234184                       365                     365
# 250536                       365                     365
# ...                          ...                     ...
# 38392995                    1125                    1125
# 38404073                       7                       7
# 38489399                    1125                    1125
# 38492461                    1125                    1125
# 38495716                       1                       1
#
#           minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# id
# 3647                         3.0                     7.0    37 months ago
# 25696                        2.0                    14.0      3 weeks ago
# 57874                        3.0                   365.0     2 months ago
# 234184                       4.9                   365.0       3 days ago
# 250536                       1.0                   365.0    17 months ago
# ...                          ...                     ...              ...
# 38392995                     1.0                  1125.0       a week ago
# 38404073                     2.0                     7.0       4 days ago
# 38489399                     1.0                  1125.0       4 days ago
# 38492461                     1.0                  1125.0            today
# 38495716                     1.0                     1.0        yesterday
#
#          has_availability  availability_30  availability_60  availability_90  \
# id
# 3647                    t               30               60               90
# 25696                   t                7               34               64
# 57874                   t                1                6               19
# 234184                  t                7               12               21
# 250536                  t                7               37               67
# ...                   ...              ...              ...              ...
# 38392995                t               29               59               89
# 38404073                t                5               11               32
# 38489399                t               26               56               86
# 38492461                t               26               56               86
# 38495716                t               28               58               88
#
#           availability_365 calendar_last_scraped  number_of_reviews  \
# id
# 3647                   365            2019-09-13                  0
# 25696                  339            2019-09-13                177
# 57874                  265            2019-09-13                231
# 234184                 162            2019-09-13                 91
# 250536                 342            2019-09-13                 11
# ...                    ...                   ...                ...
# 38392995               179            2019-09-13                  0
# 38404073               114            2019-09-13                  0
# 38489399                86            2019-09-13                  0
# 38492461                86            2019-09-13                  0
# 38495716               178            2019-09-13                  0
#
#           number_of_reviews_ltm first_review last_review  \
# id
# 3647                          0          NaN         NaN
# 25696                        17   2010-11-02  2019-08-29
# 57874                        41   2010-11-08  2019-08-27
# 234184                       12   2011-10-10  2019-08-20
# 250536                        0   2011-12-05  2017-09-25
# ...                         ...          ...         ...
# 38392995                      0          NaN         NaN
# 38404073                      0          NaN         NaN
# 38489399                      0          NaN         NaN
# 38492461                      0          NaN         NaN
# 38495716                      0          NaN         NaN
#
#           review_scores_rating  review_scores_accuracy  \
# id
# 3647                       NaN                     NaN
# 25696                     95.0                    10.0
# 57874                     97.0                    10.0
# 234184                    97.0                    10.0
# 250536                   100.0                    10.0
# ...                        ...                     ...
# 38392995                   NaN                     NaN
# 38404073                   NaN                     NaN
# 38489399                   NaN                     NaN
# 38492461                   NaN                     NaN
# 38495716                   NaN                     NaN
#
#           review_scores_cleanliness  review_scores_checkin  \
# id
# 3647                            NaN                    NaN
# 25696                          10.0                   10.0
# 57874                          10.0                   10.0
# 234184                          9.0                   10.0
# 250536                         10.0                   10.0
# ...                             ...                    ...
# 38392995                        NaN                    NaN
# 38404073                        NaN                    NaN
# 38489399                        NaN                    NaN
# 38492461                        NaN                    NaN
# 38495716                        NaN                    NaN
#
#           review_scores_communication  review_scores_location  \
# id
# 3647                              NaN                     NaN
# 25696                            10.0                    10.0
# 57874                            10.0                     9.0
# 234184                           10.0                    10.0
# 250536                           10.0                     9.0
# ...                               ...                     ...
# 38392995                          NaN                     NaN
# 38404073                          NaN                     NaN
# 38489399                          NaN                     NaN
# 38492461                          NaN                     NaN
# 38495716                          NaN                     NaN
#
#           review_scores_value requires_license license jurisdiction_names  \
# id
# 3647                      NaN                f     NaN                NaN
# 25696                     9.0                f     NaN                NaN
# 57874                    10.0                f     NaN                NaN
# 234184                   10.0                f     NaN                NaN
# 250536                   10.0                f     NaN                NaN
# ...                       ...              ...     ...                ...
# 38392995                  NaN                f     NaN                NaN
# 38404073                  NaN                f     NaN                NaN
# 38489399                  NaN                f     NaN                NaN
# 38492461                  NaN                f     NaN                NaN
# 38495716                  NaN                f     NaN                NaN
#
#           instant_bookable is_business_travel_ready  \
# id
# 3647                     0                        f
# 25696                    1                        f
# 57874                    1                        f
# 234184                   1                        f
# 250536                   0                        f
# ...                    ...                      ...
# 38392995                 1                        f
# 38404073                 0                        f
# 38489399                 1                        f
# 38492461                 1                        f
# 38495716                 1                        f
#
#                   cancellation_policy require_guest_profile_picture  \
# id
# 3647      strict_14_with_grace_period                             t
# 25696     strict_14_with_grace_period                             f
# 57874     strict_14_with_grace_period                             f
# 234184    strict_14_with_grace_period                             f
# 250536                       flexible                             f
# ...                               ...                           ...
# 38392995                     flexible                             f
# 38404073                     moderate                             f
# 38489399                     flexible                             f
# 38492461                     moderate                             f
# 38495716                     flexible                             f
#
#          require_guest_phone_verification  calculated_host_listings_count  \
# id
# 3647                                    t                               1
# 25696                                   f                               1
# 57874                                   f                               2
# 234184                                  f                               1
# 250536                                  f                               2
# ...                                   ...                             ...
# 38392995                                f                               1
# 38404073                                f                               1
# 38489399                                f                               1
# 38492461                                f                               1
# 38495716                                f                               1
#
#           calculated_host_listings_count_entire_homes  \
# id
# 3647                                                0
# 25696                                               0
# 57874                                               2
# 234184                                              1
# 250536                                              1
# ...                                               ...
# 38392995                                            0
# 38404073                                            1
# 38489399                                            0
# 38492461                                            0
# 38495716                                            0
#
#           calculated_host_listings_count_private_rooms  \
# id
# 3647                                                 1
# 25696                                                1
# 57874                                                0
# 234184                                               0
# 250536                                               1
# ...                                                ...
# 38392995                                             1
# 38404073                                             0
# 38489399                                             1
# 38492461                                             1
# 38495716                                             1
#
#           calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 3647                                                0                NaN
# 25696                                               0               1.64
# 57874                                               0               2.14
# 234184                                              0               0.94
# 250536                                              0               0.12
# ...                                               ...                ...
# 38392995                                            0                NaN
# 38404073                                            0                NaN
# 38489399                                            0                NaN
# 38492461                                            0                NaN
# 38495716                                            0                NaN
#
#           census_tracts  box_lower_latitude  box_upper_latitude  \
# id
# 3647        36061020800              40.805              40.813
# 25696       36061020800              40.805              40.813
# 57874       36061020800              40.805              40.813
# 234184      36061020800              40.805              40.813
# 250536      36061020800              40.805              40.813
# ...                 ...                 ...                 ...
# 38392995    36005044400              40.896              40.904
# 38404073    36047005202              40.615              40.623
# 38489399    36005025000              40.846              40.855
# 38492461    36005027401              40.838              40.846
# 38495716    36005023000              40.846              40.855
#
#           box_lower_longitude  box_upper_longitude  \
# id
# 3647                  -73.945              -73.933
# 25696                 -73.945              -73.933
# 57874                 -73.945              -73.933
# 234184                -73.945              -73.933
# 250536                -73.945              -73.933
# ...                       ...                  ...
# 38392995              -73.856              -73.845
# 38404073              -74.044              -74.033
# 38489399              -73.856              -73.845
# 38492461              -73.823              -73.811
# 38495716              -73.867              -73.856
#
#                                     box  crime_score    County    Borough  \
# id
# 3647      40.805,40.813,-73.945,-73.933       9942.3  New York  Manhattan
# 25696     40.805,40.813,-73.945,-73.933       9942.3  New York  Manhattan
# 57874     40.805,40.813,-73.945,-73.933       9942.3  New York  Manhattan
# 234184    40.805,40.813,-73.945,-73.933       9942.3  New York  Manhattan
# 250536    40.805,40.813,-73.945,-73.933       9942.3  New York  Manhattan
# ...                                 ...          ...       ...        ...
# 38392995  40.896,40.904,-73.856,-73.845       3166.7     Bronx      Bronx
# 38404073  40.615,40.623,-74.044,-74.033       1034.2     Kings   Brooklyn
# 38489399  40.846,40.855,-73.856,-73.845       1589.1     Bronx      Bronx
# 38492461  40.838,40.846,-73.823,-73.811        477.7     Bronx      Bronx
# 38495716  40.846,40.855,-73.867,-73.856       2743.0     Bronx      Bronx
#
#           TotalPop   Men  Women  Hispanic  White  Black  Native  Asian  \
# id
# 3647          5320  2758   2562      11.9   21.8   53.3     0.0    7.2
# 25696         5320  2758   2562      11.9   21.8   53.3     0.0    7.2
# 57874         5320  2758   2562      11.9   21.8   53.3     0.0    7.2
# 234184        5320  2758   2562      11.9   21.8   53.3     0.0    7.2
# 250536        5320  2758   2562      11.9   21.8   53.3     0.0    7.2
# ...            ...   ...    ...       ...    ...    ...     ...    ...
# 38392995      3576  1643   1933      15.6    3.2   77.0     0.0    0.6
# 38404073      2436  1098   1338       8.8   82.4    2.7     0.0    5.6
# 38489399      2663  1151   1512      29.6   54.8    1.2     0.0   12.5
# 38492461      4576  2254   2322       9.1   86.3    0.0     0.0    4.5
# 38495716      3334  1595   1739      57.7   22.7    9.6     0.0    9.4
#
#           Citizen   Income  IncomeErr  IncomePerCap  IncomePerCapErr  Poverty  \
# id
# 3647         3683  42220.0     8831.0       37019.0           7619.0     25.6
# 25696        3683  42220.0     8831.0       37019.0           7619.0     25.6
# 57874        3683  42220.0     8831.0       37019.0           7619.0     25.6
# 234184       3683  42220.0     8831.0       37019.0           7619.0     25.6
# 250536       3683  42220.0     8831.0       37019.0           7619.0     25.6
# ...           ...      ...        ...           ...              ...      ...
# 38392995     2399  67727.0    15227.0       23999.0           2958.0     17.0
# 38404073     2014  68958.0    10596.0       53475.0           5917.0      5.2
# 38489399     1558  54726.0    16587.0       31680.0           5629.0     11.8
# 38492461     3632  80673.0    10749.0       36809.0           4471.0      4.5
# 38495716     1896  43929.0    19129.0       17638.0           2718.0     23.5
#
#           ChildPoverty  Professional  Service  Office  Construction  \
# id
# 3647              50.1          42.3     13.7    30.4           3.5
# 25696             50.1          42.3     13.7    30.4           3.5
# 57874             50.1          42.3     13.7    30.4           3.5
# 234184            50.1          42.3     13.7    30.4           3.5
# 250536            50.1          42.3     13.7    30.4           3.5
# ...                ...           ...      ...     ...           ...
# 38392995          18.1          27.6     35.0    20.6           7.5
# 38404073           0.0          57.2     10.0    24.9           2.0
# 38489399          18.3          31.6     43.9    15.1           7.6
# 38492461           0.0          34.4     17.2    26.1          12.2
# 38495716          34.8          25.7     24.4    29.4           5.8
#
#           Production  Drive  Carpool  Transit  Walk  OtherTransp  WorkAtHome  \
# id
# 3647            10.1    8.8      2.1     70.8   7.1          4.9         6.3
# 25696           10.1    8.8      2.1     70.8   7.1          4.9         6.3
# 57874           10.1    8.8      2.1     70.8   7.1          4.9         6.3
# 234184          10.1    8.8      2.1     70.8   7.1          4.9         6.3
# 250536          10.1    8.8      2.1     70.8   7.1          4.9         6.3
# ...              ...    ...      ...      ...   ...          ...         ...
# 38392995         9.2   36.3      3.3     52.6   0.0          3.3         4.5
# 38404073         5.9   28.6      2.5     62.7   0.9          0.0         5.3
# 38489399         1.9   32.1      5.1     37.9  18.4          2.3         4.3
# 38492461        10.1   51.3      6.7     32.4   7.3          1.8         0.5
# 38495716        14.7   22.3      6.3     63.2   3.8          0.0         4.5
#
#           MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# id
# 3647             36.4      2695         78.7        11.1          10.2
# 25696            36.4      2695         78.7        11.1          10.2
# 57874            36.4      2695         78.7        11.1          10.2
# 234184           36.4      2695         78.7        11.1          10.2
# 250536           36.4      2695         78.7        11.1          10.2
# ...               ...       ...          ...         ...           ...
# ...
# 38489399           0             0       0             0             0
# 38492461           0             0       0             1             0
# 38495716           0             0       0             0             0
#
#           Douglaston  Dyker Heights  East Morrisania  Edenwald  Edgemere  \
# id
# 3647               0              0                0         0         0
# 25696              0              0                0         0         0
# 57874              0              0                0         0         0
# 234184             0              0                0         0         0
# 250536             0              0                0         0         0
# ...              ...            ...              ...       ...       ...
# 38392995           0              0                0         0         0
# 38404073           0              0                0         0         0
# 38489399           0              0                0         0         0
# 38492461           0              0                0         0         0
# 38495716           0              0                0         0         0
#
#           Eltingville  Emerson Hill  Far Rockaway  Fordham  Fort Wadsworth  \
# id
# 3647                0             0             0        0               0
# 25696               0             0             0        0               0
# 57874               0             0             0        0               0
# 234184              0             0             0        0               0
# 250536              0             0             0        0               0
# ...               ...           ...           ...      ...             ...
# 38392995            0             0             0        0               0
# 38404073            0             0             0        0               0
# 38489399            0             0             0        0               0
# 38492461            0             0             0        0               0
# 38495716            0             0             0        0               0
#
#           Fresh Meadows  Gerritsen Beach  Grant City  Great Kills  \
# id
# 3647                  0                0           0            0
# 25696                 0                0           0            0
# 57874                 0                0           0            0
# 234184                0                0           0            0
# 250536                0                0           0            0
# ...                 ...              ...         ...          ...
# 38392995              0                0           0            0
# 38404073              0                0           0            0
# 38489399              0                0           0            0
# 38492461              0                0           0            0
# 38495716              0                0           0            0
#
#           Grymes Hill  Hollis  Holliswood  Howard Beach  Howland Hook  \
# id
# 3647                0       0           0             0             0
# 25696               0       0           0             0             0
# 57874               0       0           0             0             0
# 234184              0       0           0             0             0
# 250536              0       0           0             0             0
# ...               ...     ...         ...           ...           ...
# 38392995            0       0           0             0             0
# 38404073            0       0           0             0             0
# 38489399            0       0           0             0             0
# 38492461            0       0           0             0             0
# 38495716            0       0           0             0             0
#
#           Huguenot  Hunts Point  Jamaica Estates  Jamaica Hills  \
# id
# 3647             0            0                0              0
# 25696            0            0                0              0
# 57874            0            0                0              0
# 234184           0            0                0              0
# 250536           0            0                0              0
# ...            ...          ...              ...            ...
# 38392995         0            0                0              0
# 38404073         0            0                0              0
# 38489399         0            0                0              0
# 38492461         0            0                0              0
# 38495716         0            0                0              0
#
#           Kew Gardens Hills  Laurelton  Lighthouse Hill  Little Neck  \
# id
# 3647                      0          0                0            0
# 25696                     0          0                0            0
# 57874                     0          0                0            0
# 234184                    0          0                0            0
# 250536                    0          0                0            0
# ...                     ...        ...              ...          ...
# 38392995                  0          0                0            0
# 38404073                  0          0                0            0
# 38489399                  0          0                0            0
# 38492461                  0          0                0            0
# 38495716                  0          0                0            0
#
#           Manhattan Beach  Marble Hill  Melrose  Midland Beach  Mill Basin  \
# id
# 3647                    0            0        0              0           0
# 25696                   0            0        0              0           0
# 57874                   0            0        0              0           0
# 234184                  0            0        0              0           0
# 250536                  0            0        0              0           0
# ...                   ...          ...      ...            ...         ...
# 38392995                0            0        0              0           0
# 38404073                0            0        0              0           0
# 38489399                0            0        0              0           0
# 38492461                0            0        0              0           0
# 38495716                0            0        0              0           0
#
#           Morris Park  Morrisania  Mount Hope  Navy Yard  Neponsit  \
# id
# 3647                0           0           0          0         0
# 25696               0           0           0          0         0
# 57874               0           0           0          0         0
# 234184              0           0           0          0         0
# 250536              0           0           0          0         0
# ...               ...         ...         ...        ...       ...
# 38392995            0           0           0          0         0
# 38404073            0           0           0          0         0
# 38489399            1           0           0          0         0
# 38492461            0           0           0          0         0
# 38495716            0           0           0          0         0
#
#           New Brighton  New Dorp  New Dorp Beach  North Riverdale  Norwood  \
# id
# 3647                 0         0               0                0        0
# 25696                0         0               0                0        0
# 57874                0         0               0                0        0
# 234184               0         0               0                0        0
# 250536               0         0               0                0        0
# ...                ...       ...             ...              ...      ...
# 38392995             0         0               0                0        0
# 38404073             0         0               0                0        0
# 38489399             0         0               0                0        0
# 38492461             0         0               0                0        0
# 38495716             0         0               0                0        0
#
#           Oakwood  Olinville  Parkchester  Pelham Bay  Pelham Gardens  \
# id
# 3647            0          0            0           0               0
# 25696           0          0            0           0               0
# 57874           0          0            0           0               0
# 234184          0          0            0           0               0
# 250536          0          0            0           0               0
# ...           ...        ...          ...         ...             ...
# 38392995        0          0            0           0               0
# 38404073        0          0            0           0               0
# 38489399        0          0            0           0               0
# 38492461        0          0            0           0               0
# 38495716        0          0            0           0               0
#
#           Port Richmond  Prince's Bay  Randall Manor  Richmondtown  Riverdale  \
# id
# 3647                  0             0              0             0          0
# 25696                 0             0              0             0          0
# 57874                 0             0              0             0          0
# 234184                0             0              0             0          0
# 250536                0             0              0             0          0
# ...                 ...           ...            ...           ...        ...
# 38392995              0             0              0             0          0
# 38404073              0             0              0             0          0
# 38489399              0             0              0             0          0
# 38492461              0             0              0             0          0
# 38495716              0             0              0             0          0
#
#           Rosebank  Rosedale  Rossville  Schuylerville  Sea Gate  Silver Lake  \
# id
# 3647             0         0          0              0         0            0
# 25696            0         0          0              0         0            0
# 57874            0         0          0              0         0            0
# 234184           0         0          0              0         0            0
# 250536           0         0          0              0         0            0
# ...            ...       ...        ...            ...       ...          ...
# 38392995         0         0          0              0         0            0
# 38404073         0         0          0              0         0            0
# 38489399         0         0          0              0         0            0
# 38492461         0         0          0              0         0            0
# 38495716         0         0          0              0         0            0
#
#           Soundview  South Beach  South Ozone Park  Springfield Gardens  \
# id
# 3647              0            0                 0                    0
# 25696             0            0                 0                    0
# 57874             0            0                 0                    0
# 234184            0            0                 0                    0
# 250536            0            0                 0                    0
# ...             ...          ...               ...                  ...
# 38392995          0            0                 0                    0
# 38404073          0            0                 0                    0
# 38489399          0            0                 0                    0
# 38492461          0            0                 0                    0
# 38495716          0            0                 0                    0
#
#           Stuyvesant Town  Throgs Neck  Todt Hill  Tremont  Unionport  \
# id
# 3647                    0            0          0        0          0
# 25696                   0            0          0        0          0
# 57874                   0            0          0        0          0
# 234184                  0            0          0        0          0
# 250536                  0            0          0        0          0
# ...                   ...          ...        ...      ...        ...
# 38392995                0            0          0        0          0
# 38404073                0            0          0        0          0
# 38489399                0            0          0        0          0
# 38492461                0            0          0        0          0
# 38495716                0            0          0        0          0
#
#           Van Nest  West Brighton  West Farms  Westchester Square  \
# id
# 3647             0              0           0                   0
# 25696            0              0           0                   0
# 57874            0              0           0                   0
# 234184           0              0           0                   0
# 250536           0              0           0                   0
# ...            ...            ...         ...                 ...
# 38392995         0              0           0                   0
# 38404073         0              0           0                   0
# 38489399         0              0           0                   0
# 38492461         0              0           0                   0
# 38495716         1              0           0                   0
#
#           Westerleigh  Whitestone  Williamsbridge  Willowbrook  Woodhaven  \
# id
# 3647                0           0               0            0          0
# 25696               0           0               0            0          0
# 57874               0           0               0            0          0
# 234184              0           0               0            0          0
# 250536              0           0               0            0          0
# ...               ...         ...             ...          ...        ...
# 38392995            0           0               0            0          0
# 38404073            0           0               0            0          0
# 38489399            0           0               0            0          0
# 38492461            0           0               0            0          0
# 38495716            0           0               0            0          0
#
#           Woodrow
# id
# 3647            0
# 25696           0
# 57874           0
# 234184          0
# 250536          0
# ...           ...
# 38392995        0
# 38404073        0
# 38489399        0
# 38492461        0
# 38495716        0
#
# [47969 rows x 413 columns]

# %%
corr = ACeCr.corr()['number_of_reviews']
corr = corr
corr.sort_values().tail(30)
# Out:
# East Elmhurst                  0.082040
# review_scores_checkin          0.084980
# review_scores_cleanliness      0.086037
# Air conditioning               0.089384
# Laptop friendly workspace      0.092864
# Heating                        0.098916
# Pets on property               0.100062
# availability_90                0.102905
# No stairs or steps to enter    0.106293
# guests_included                0.117588
# Shampoo                        0.138042
# Hangers                        0.144055
# Iron                           0.179263
# Extra pillows and blankets     0.181150
# availability_365               0.192853
# Hair dryer                     0.202246
# Family/kid friendly            0.202910
# Coffee maker                   0.210481
# Luggage dropoff allowed        0.216372
# Self check-in                  0.239270
# Hot water                      0.244562
# Free parking                   0.259403
# host_is_superhost              0.319181
# reviews_per_month              0.550782
# number_of_reviews_ltm          0.772801
# number_of_reviews              1.000000
# thumbnail_url                       NaN
# medium_url                          NaN
# xl_picture_url                      NaN
# host_acceptance_rate                NaN
# Name: number_of_reviews, dtype: float64

# %%
corr.sort_values().head(30)
# Out:
# host_id                                       -0.141390
# square_feet                                   -0.101288
# minimum_minimum_nights                        -0.087576
# minimum_nights                                -0.087373
# White                                         -0.082807
# minimum_nights_avg_ntm                        -0.082471
# IncomePerCap                                  -0.079211
# maximum_minimum_nights                        -0.071107
# Income                                        -0.070901
# host_total_listings_count                     -0.070328
# host_listings_count                           -0.070328
# calculated_host_listings_count                -0.070020
# Professional                                  -0.068489
# IncomePerCapErr                               -0.067090
# calculated_host_listings_count_entire_homes   -0.067002
# Kitchen                                       -0.064737
# Walk                                          -0.062547
# PrivateWork                                   -0.061877
# Employed                                      -0.055036
# Pets allowed                                  -0.048521
# price                                         -0.047139
# IncomeErr                                     -0.044577
# Citizen                                       -0.043647
# Midtown                                       -0.041112
# OtherTransp                                   -0.039674
# Financial District                            -0.039112
# Women                                         -0.038353
# TotalPop                                      -0.036506
# Murray Hill                                   -0.033271
# bathrooms                                     -0.033078
# Name: number_of_reviews, dtype: float64

# %%
imp_df = ACeCr.copy()
imp_df = imp_df[[
    'accommodates','bathrooms','IncomePerCap','Professional','WorkAtHome','White','Citizen','host_response_rate','price','guests_included'  
    ,'Hair dryer', 'Iron', 'Coffee maker', 'Extra pillows and blankets', 'Luggage dropoff allowed', 'Lock on bedroom door'
    ,'private','new','great','heart','comfortable'
    ,'Walk','Drive','Carpool'
    ,'beds','bedrooms','Office','MeanCommute'
    ,'Service','Poverty','Unemployment','Construction','Transit','Production','Black','Hispanic','crime_score'
    ,'room_type','property_type', 'number_of_reviews'
    ,'longitude','Midtown','Bushwick','Bedford-Stuyvesant'
    ,'minimum_nights','reviews_per_month','calculated_host_listings_count','availability_365'
]]
imp_df['host_response_rate'] = imp_df['host_response_rate'].fillna('0%')
imp_df['host_response_rate'] = imp_df['host_response_rate'].map(lambda x: str(x)[:-1])


# imp_df['neighbourhood'], neighbourhood_map = pd.factorize(ACeCr['neighbourhood'])
imp_df['property_type'], property_type_map = pd.factorize(ACeCr['property_type'])
# imp_df['bed_type'], bed_type_map = pd.factorize(ACeCr['bed_type'])
imp_df['room_type'], room_type_map = pd.factorize(ACeCr['room_type'])
# imp_df['zipcode'], zipcode_map = pd.factorize(ACeCr['zipcode'])

# %%
X = imp_df.drop('price', axis='columns').values
y = imp_df['price'].values

const_params = {
    'objective':                      'regression', 
    'metric':                         'rmse',
    'n_jobs':                         -1
}

tuning_parameters = {
    'learning_rate':                  [0.11], 
    'max_depth':                      [5], 
    'n_estimators':                   [300], 
    'random_state':                   [0],
#     'num_leaves':                     [1000]
}

def rmse(y_true, y_pred): return abs(np.sqrt(mean_squared_error(y_true, y_pred)))
scorer = make_scorer(rmse, greater_is_better=False)

grid = GridSearchCV(lgbm.LGBMRegressor(**const_params), 
                    tuning_parameters, 
                    cv=StratifiedKFold(5), 
                    scoring=scorer, 
                    n_jobs=-1)

grid.fit(X, y)

print(f'Best parameters {grid.best_params_}.')
print(f'Best RMSE is {-1*grid.best_score_}.')
# Out:
# C:\Anaconda\envs\py36\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Anaconda\envs\py36\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 300, 'random_state': 0}.
# Best RMSE is 162.07733450345253.

# %%
imp_df['number_of_reviews'].hist()

# %%
import seaborn as sns
# %matplotlib inline

corr = imp_df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
(pd.Series(grid.best_estimator_.feature_importances_, 
           index=imp_df.drop('price', axis='columns').columns.tolist()).sort_values(ascending=False)
 .plot.bar(color='steelblue', figsize=(16, 7)));

# %%
imp_df.dropna(inplace=True)

# %%
import statsmodels.api as sm
X = imp_df.drop('price', axis='columns')
y = imp_df['price']

model_price = sm.OLS(y, X.astype(float)).fit()
model_price.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.484
# Model:                            OLS   Adj. R-squared (uncentered):              0.483
# Method:                 Least Squares   F-statistic:                              761.9
# Date:                Sun, 15 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        19:29:39   Log-Likelihood:                     -2.5146e+05
# No. Observations:               38226   AIC:                                  5.030e+05
# Df Residuals:                   38179   BIC:                                  5.034e+05
# Df Model:                          47
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# accommodates                      27.8839      0.836     33.337      0.000      26.245      29.523
# bathrooms                         54.1785      2.394     22.630      0.000      49.486      58.871
# IncomePerCap                       0.0006      6e-05     10.575      0.000       0.001       0.001
# Professional                     -15.6966     11.440     -1.372      0.170     -38.118       6.725
# WorkAtHome                        -0.1633      0.477     -0.343      0.732      -1.098       0.771
# White                             -0.3625      0.094     -3.867      0.000      -0.546      -0.179
# Citizen                            0.0009      0.001      1.739      0.082      -0.000       0.002
# host_response_rate                -0.0031      0.025     -0.124      0.902      -0.053       0.047
# guests_included                    1.2659      0.956      1.324      0.186      -0.608       3.140
# Hair dryer                         1.1858      2.329      0.509      0.611      -3.379       5.750
# Iron                               1.2850      2.261      0.568      0.570      -3.147       5.717
# Coffee maker                       3.2381      2.346      1.380      0.168      -1.361       7.837
# Extra pillows and blankets        -2.5828      2.451     -1.054      0.292      -7.387       2.221
# Luggage dropoff allowed            4.9019      2.578      1.901      0.057      -0.151       9.955
# Lock on bedroom door              -7.6542      2.025     -3.779      0.000     -11.624      -3.685
# private                            3.3063      2.213      1.494      0.135      -1.030       7.643
# new                               -0.7456      2.615     -0.285      0.776      -5.871       4.380
# great                             -4.5031      2.504     -1.799      0.072      -9.410       0.404
# heart                              6.9453      2.421      2.869      0.004       2.201      11.690
# comfortable                        1.3312      2.888      0.461      0.645      -4.330       6.992
# Walk                              -1.1621      0.371     -3.131      0.002      -1.890      -0.435
# Drive                             -1.8849      0.361     -5.219      0.000      -2.593      -1.177
# Carpool                           -1.5759      0.546     -2.889      0.004      -2.645      -0.507
# beds                             -10.0982      1.281     -7.883      0.000     -12.609      -7.587
# bedrooms                          25.6186      1.771     14.466      0.000      22.147      29.090
# Office                           -15.5848     11.428     -1.364      0.173     -37.984       6.814
# MeanCommute                       -2.1844      0.272     -8.019      0.000      -2.718      -1.650
# Service                          -16.1969     11.431     -1.417      0.157     -38.603       6.209
# Poverty                            0.1765      0.140      1.262      0.207      -0.098       0.451
# Unemployment                       0.1846      0.270      0.682      0.495      -0.346       0.715
# Construction                     -14.5936     11.452     -1.274      0.203     -37.040       7.853
# Transit                           -1.3170      0.348     -3.780      0.000      -2.000      -0.634
# Production                       -16.2271     11.420     -1.421      0.155     -38.610       6.156
# Black                             -0.1579      0.083     -1.895      0.058      -0.321       0.005
# Hispanic                          -0.2432      0.090     -2.710      0.007      -0.419      -0.067
# crime_score                        0.0010      0.000      3.197      0.001       0.000       0.002
# room_type                         19.9299      1.865     10.688      0.000      16.275      23.585
# property_type                      3.3714      0.427      7.900      0.000       2.535       4.208
# number_of_reviews                 -0.1103      0.022     -4.920      0.000      -0.154      -0.066
# longitude                        -23.3836     15.442     -1.514      0.130     -53.650       6.883
# Midtown                            6.2775      6.680      0.940      0.347      -6.815      19.370
# Bushwick                         -12.3408      4.770     -2.587      0.010     -21.691      -2.991
# Bedford-Stuyvesant               -15.5471      3.872     -4.016      0.000     -23.136      -7.959
# minimum_nights                    -0.0653      0.050     -1.317      0.188      -0.162       0.032
# reviews_per_month                 -4.0314      0.694     -5.812      0.000      -5.391      -2.672
# calculated_host_listings_count    -0.0028      0.030     -0.091      0.927      -0.062       0.056
# availability_365                   0.0571      0.008      7.049      0.000       0.041       0.073
# ==============================================================================
# Omnibus:                   102180.344   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3748709462.565
# Skew:                          32.356   Prob(JB):                         0.00
# Kurtosis:                    1535.782   Cond. No.                     1.93e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Rat sightings

# %% [markdown]
# ## Viz

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
cities.plot()

# %%
world.plot()

# %%
boros = gpd.read_file(gpd.datasets.get_path("nybb"))
boros.BoroName
boro_locations = gpd.tools.geocode(boros.BoroName)

# %%
fig, ax = plt.subplots()
boros.to_crs({"init": "epsg:4326"}).plot(ax=ax, color="white", edgecolor="black");
boro_locations.plot(ax=ax, color="red");

# %%
gpd.datasets.available
