# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd

# %matplotlib inline

plt.rcParams['figure.figsize'] = [20,15]
plt.rcParams['figure.dpi'] = 250

# %%
nyc_census_tracts_shape = gpd.read_file('geo/nyu_2451_34505.shp')

# %%
nyc_census_tracts_shape.plot();
